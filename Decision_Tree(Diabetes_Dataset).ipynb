# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreeKeshavan/Machine_Learning/blob/main/Decision_Tree(Diabetes_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score
import matplotlib.pyplot as plt
from sklearn import tree

# %%
df = pd.read_csv('/content/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### **Prediction**

# %%
X = df.drop(['Outcome'],axis=1)
y = df['Outcome']

dt = DecisionTreeClassifier()
dt.fit(X,y)
prediction = dt.predict(X)
df['prediction'] = prediction
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  prediction
# 0                       0.627   50        1           1
# ...

# %% [markdown]
# ### **Confusion_matrix,Accuracy_score**

# %%
print(confusion_matrix(y,prediction))
# Out:
# [[500   0]
#  [  0 268]]

# %%
print(accuracy_score(y,prediction))
# Out:
# 1.0

# %% [markdown]
# ### **TO VIEW(Clarity)**

# %%
fig = plt.figure(figsize = (50,50)) #the size to visualise the decision tree
tree.plot_tree(dt,feature_names= X.columns,filled = True) #tree module is to visualise the tree clearly/ high clarity
plt.savefig('Decision_Tree.pdf') # to save the decision tree as pdf
plt.show()

# %% [markdown]
# ### **prooning**

# %%
dfc = DecisionTreeClassifier(max_depth=2) #to choose the maximum depth

# %% [markdown]
# ### **Entropy**

# %%
dfc = DecisionTreeClassifier(criterion = ' entrophy',max_depth=2) #criterion is to choose which method to decission tree

# %% [markdown]
# ### **splitter**

# %%
#There are two methods od splitting (random,best)
dfc = DecisionTreeClassifier(criterion = ' entrophy',max_depth=2,splitter="random")
dfc = DecisionTreeClassifier(criterion = ' entrophy',max_depth=2,splitter="best")

# %% [markdown]
# ## **Titanic Dataset**

# %%
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(df['sex'])
df['sex'] = le.transform(df['sex'])

le.fit(df['class'])
df['class'] = le.transform(df['class'])

le.fit(df['embarked'])
df['embarked'] = le.transform(df['embarked'])

le.fit(df['who'])
df['who'] = le.transform(df['who'])

le.fit(df['adult_male'])
df['adult_male'] = le.transform(df['adult_male'])

le.fit(df['embark_town'])
df['embark_town'] = le.transform(df['embark_town'])

le.fit(df['deck'])
df['deck'] = le.transform(df['deck'])

le.fit(df['alive'])
df['alive'] = le.transform(df['alive'])

le.fit(df['alone'])
df['alone'] = le.transform(df['alone'])
7 

print(df)
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0           0       3    1  22.0      1      0   7.2500         2      2    1
# 1           1       1    0  38.0      1      0  71.2833         0      0    2
# 2           1       3    0  26.0      0      0   7.9250         2      2    2
# 3           1       1    0  35.0      1      0  53.1000         2      0    2
# 4           0       3    1  35.0      0      0   8.0500         2      2    1
# ..        ...     ...  ...   ...    ...    ...      ...       ...    ...  ...
# 886         0       2    1  27.0      0      0  13.0000         2      1    1
# 887         1       1    0  19.0      0      0  30.0000         2      0    2
# 888         0       3    0  19.0      1      2  23.4500         2      2    2
# 889         1       1    1  26.0      0      0  30.0000         0      0    1
# 890         0       3    1  32.0      0      0   7.7500         1      2    1
#
# ...

# %%
df = df.fillna(method = 'pad')
X = df.drop(['survived', 'alive'],axis = 1)
y = df['survived']
dtc = DecisionTreeClassifier(criterion = 'entropy',max_depth= 4,splitter = 'best')
dtc.fit(X,y)
prediction = dtc.predict(X)
df['prediction'] = prediction
print(df)
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0           0       3    1  22.0      1      0   7.2500         2      2    1
# 1           1       1    0  38.0      1      0  71.2833         0      0    2
# 2           1       3    0  26.0      0      0   7.9250         2      2    2
# 3           1       1    0  35.0      1      0  53.1000         2      0    2
# 4           0       3    1  35.0      0      0   8.0500         2      2    1
# ..        ...     ...  ...   ...    ...    ...      ...       ...    ...  ...
# 886         0       2    1  27.0      0      0  13.0000         2      1    1
# 887         1       1    0  19.0      0      0  30.0000         2      0    2
# 888         0       3    0  19.0      1      2  23.4500         2      2    2
# 889         1       1    1  26.0      0      0  30.0000         0      0    1
# 890         0       3    1  32.0      0      0   7.7500         1      2    1
#
# ...

# %%
print(confusion_matrix(y,prediction))
print(accuracy_score(y,prediction))
# Out:
# [[549   0]
#  [  0 342]]
# 1.0

# %% [markdown]
# # **BAGGING - Random Forest**

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn import tree
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
x,y = make_classification(n_samples=1000,n_features=4,random_state=0,shuffle=True)#to make own sample dataset
# n_samples = number of samples we want to make
# n_features = number of features/columns we want
# random_state = is to choose the same data each_time without suffleing
# shuffle = to suffle the datas each tym

# %%
dt = DecisionTreeClassifier()
dt.fit(x,y)
prediction = dt.predict(x)

# %%
fig = plt.figure(figsize = (50,50))
tree.plot_tree(dt,filled=True)
plt.savefig('decision.pdf')
plt.show()

# %%
rf = RandomForestClassifier()
rf.fit(x,y)
# we dont need to give predict in random forest
# Out:
# RandomForestClassifier()

# %%
print(confusion_matrix(y,prediction))
# Out:
# [[498   0]
#  [  0 502]]

# %% [markdown]
# ## **BOOSTING**

# %%
ab = AdaBoostClassifier()
ab.fit(X,y)
prediction = ab.predict(X)

#to check performance (train data) - adaboost
print(confusion_matrix(y,prediction))
print(accuracy_score(y,prediction))
