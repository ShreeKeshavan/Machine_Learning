# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreeKeshavan/Machine_Learning/blob/main/Case_study_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import time
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix,f1_score

# %%
data = pd.read_csv('creditcard.csv')

# %% [markdown]
# Analysing Data

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data['Class'].unique() #target variable
# Out:
# array([0, 1])

# %%
data.isnull().sum()  #no null values in this dataset
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data['Class'].value_counts() #to check data set is imbalanced or not #no obj type in this data so encoding not required
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# Preprocessing

# %% [markdown]
# Duplicate check

# %%
data.duplicated().sum() #to identify/check  duplicates
# Out:
# 1081

# %%
data.drop_duplicates(inplace=True) #to remove duplicates

# %%
data.shape
# Out:
# (283726, 31)

# %%
data.duplicated().sum() #to identify/check  duplicates
# Out:
# 0

# %% [markdown]
# Splitting

# %%
X = data.iloc[:,0:-1]
y = data.iloc[:, :-1]

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %%
X.drop('Time', axis=1, inplace=True)

# %%
X
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# Preprocessing

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)

# %%
X_test = ss.transform(X_test)

# %%
#Logistic regression
logreg = LogisticRegression()
start = time.time()
logreg.fit(X_train,y_train)
end =  time.time()
print('time taken : ',end - start)
# Out:
# time taken :  2.3543286323547363

# %%
start = time.time()
print(logreg.score(X_test,y_test))
end =  time.time()
print('time taken : ',end - start)
# Out:
# 0.9991541254009093
# time taken :  0.03197193145751953

# %%
#SVC
svc = SVC()
start = time.time()
svc.fit(X_train,y_train)
end =  time.time()
print('time taken : ',end - start)
# Out:
# time taken :  272.6862642765045

# %%
start = time.time()
print(svc.score(X_test,y_test))
end =  time.time()
print('time taken : ',end - start)
# Out:
# 0.9994008388256441
# time taken :  17.32711434364319

# %%
#KNN
knn = KNeighborsClassifier()
start = time.time()
knn.fit(X_train,y_train)
end =  time.time()
print('time taken : ',end - start)
# Out:
# time taken :  0.05243968963623047

# %%
start = time.time()
print(knn.score(X_test,y_test))
end =  time.time()
print('time taken : ',end - start)
# Out:
# 0.9994360836006062
# time taken :  81.03054785728455

# %%
#Decision Tree
dtc = DecisionTreeClassifier()
start = time.time()
dtc.fit(X_train,y_train)
end =  time.time()
print('time taken : ',end - start)
# Out:
# time taken :  18.674901962280273

# %%
start = time.time()
print(dtc.score(X_test,y_test))
end =  time.time()
print('time taken : ',end - start)
# Out:
# 0.9992774821132767
# time taken :  0.022749900817871094

# %%
#Random forest
rfc = RandomForestClassifier()
start = time.time()
rfc.fit(X_train,y_train)
end =  time.time()
print('time taken : ',end - start)
# Out:
# time taken :  282.6132433414459

# %%
start = time.time()
print(rfc.score(X_test,y_test))
end =  time.time()
print('time taken : ',end - start)
# Out:
# 0.9995594403129736
# time taken :  0.6462693214416504

# %%
#Gradient Boosting
gdc = GradientBoostingClassifier()
start = time.time()
gdc.fit(X_train,y_train)
end =  time.time()
print('time taken : ',end - start)
# Out:
# time taken :  404.0935287475586

# %%
start = time.time()
print(gdc.score(X_test,y_test))
end =  time.time()
print('time taken : ',end - start)
# Out:
# 0.9992069925633524
# time taken :  0.07783699035644531

# %%
# ?f1_score #to view documentation

# %%
y_pred_logreg = logreg.predict(X_test)
f1_score(y_test,y_pred_logreg)
# Out:
# 0.6712328767123288

# %%
y_pred_svc = svc.predict(X_test)
f1_score(y_test,y_pred_svc)
# Out:
# 0.7702702702702702

# %%
y_pred_knn = knn.predict(X_test)
f1_score(y_test,y_pred_knn)
# Out:
# 0.7974683544303797

# %%
y_pred_dtc = dtc.predict(X_test)
f1_score(y_test,y_pred_dtc)
# Out:
# 0.7734806629834253

# %%
y_pred_rfc = rfc.predict(X_test)
f1_score(y_test,y_pred_rfc)
# Out:
# 0.8481012658227848

# %%
y_pred_gdc = gdc.predict(X_test)
f1_score(y_test,y_pred_gdc)
# Out:
# 0.689655172413793

# %%
confusion_matrix(y_test,y_pred_logreg )
# Out:
# array([[56649,    10],
#        [   38,    49]])

# %%
confusion_matrix(y_test,y_pred_svc )
# Out:
# array([[56655,     4],
#        [   30,    57]])

# %%
confusion_matrix(y_test,y_pred_knn )
# Out:
# array([[56651,     8],
#        [   24,    63]])

# %%
confusion_matrix(y_test,y_pred_dtc )
# Out:
# array([[56635,    24],
#        [   17,    70]])

# %%
confusion_matrix(y_test,y_pred_rfc )
# Out:
# array([[56655,     4],
#        [   20,    67]])

# %%
confusion_matrix(y_test,y_pred_gdc )
# Out:
# array([[56651,     8],
#        [   37,    50]])
